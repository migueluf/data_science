# %% [markdown]
# <a href="https://colab.research.google.com/github/migueluf/data_science/blob/main/exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-34a89741-24a8-468d-987e-4e5ee2c4e213" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34a89741-24a8-468d-987e-4e5ee2c4e213">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("AdventureWorks.xlsx")

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
df["Valor Venda"].sum()
# Out:
# 5984606.1426

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data Venda      904 non-null    datetime64[ns]
#  1   Data Envio      904 non-null    datetime64[ns]
#  2   ID Loja         904 non-null    int64
#  3   ID Produto      904 non-null    int64
#  4   ID Cliente      904 non-null    int64
#  5   No. Venda       904 non-null    object
#  6   Custo Unitário  904 non-null    float64
#  7   Preço Unitário  904 non-null    float64
#  8   Quantidade      904 non-null    int64
#  9   Valor Desconto  904 non-null    float64
#  10  Valor Venda     904 non-null    float64
#  11  Produto         904 non-null    object
#  12  Fabricante      904 non-null    object
#  13  Marca           904 non-null    object
#  14  Classe          904 non-null    object
#  15  Cor             904 non-null    object
# ...

# %%
df.groupby("ID Cliente")["ID Cliente"].count()
# Out:
# ID Cliente
# 18815     2
# 18816     6
# 18819     8
# 18822     2
# 18823     4
#          ..
# 19137    10
# 19138     6
# 19139     7
# 19140     6
# 19145     6
# Name: ID Cliente, Length: 168, dtype: int64

# %%
maior_comprador = df.loc[df["ID Cliente"] == 18839]

# %%
df["Qtd_Compras_Cliente"] = df["ID Cliente"].count()

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 808 2009-02-09 2009-02-19      307         384       19116  200902093CS699
# 630 2008-02-28 2008-03-06      199        1155       18823  200802284CS578
# 654 2008-01-20 2008-01-30      199        1203       18816  200801204CS560
# 202 2009-06-04 2009-06-16      306        1226       19068  200906044CS748
# 720 2009-07-19 2009-07-31      199        2496       18968  200907195CS879
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 808          348.58          758.00           6         909.600     3638.400
# 630          324.69          980.00           5         245.000     4655.000
# 654          324.69          980.00           5         245.000     4655.000
# 202          330.99          999.00          12           0.000    11988.000
# 720            5.09            9.99         576         575.424     5178.816
#
# ...

# %%
df.groupby("Fabricante")["Quantidade"].mean().plot.bar()

# %%
df["lucro"] = df["Preço Unitário"] - df["Custo Unitário"]

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  Qtd_Compras_Cliente   lucro
# 0  Regular  Red                  904  409.42

# %%
df.groupby("Fabricante")["lucro"].sum().plot.barh()

# %%
df["TempoEnvio"] = df["Data Envio"] - df["Data Venda"]

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  Qtd_Compras_Cliente   lucro TempoEnvio
# 0  Regular  Red                  904  409.42    20 days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Data Venda           904 non-null    datetime64[ns]
#  1   Data Envio           904 non-null    datetime64[ns]
#  2   ID Loja              904 non-null    int64
#  3   ID Produto           904 non-null    int64
#  4   ID Cliente           904 non-null    int64
#  5   No. Venda            904 non-null    object
#  6   Custo Unitário       904 non-null    float64
#  7   Preço Unitário       904 non-null    float64
#  8   Quantidade           904 non-null    int64
#  9   Valor Desconto       904 non-null    float64
#  10  Valor Venda          904 non-null    float64
#  11  Produto              904 non-null    object
#  12  Fabricante           904 non-null    object
#  13  Marca                904 non-null    object
#  14  Classe               904 non-null    object
# ...

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  Qtd_Compras_Cliente   lucro TempoEnvio
# 0  Regular  Red                  904  409.42    20 days

# %%
df["TempoEnvio"] = (df["Data Envio"] - df["Data Venda"]).dt.days

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  Qtd_Compras_Cliente   lucro  TempoEnvio
# 0  Regular  Red                  904  409.42          20

# %%
atraso = df.loc[df["TempoEnvio"] > 10]

# %%
atraso.head()
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0  2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 9  2008-10-16 2008-10-27      307         384       19107  200810163CS646
# 10 2008-10-21 2008-11-01      307         384       19107  200810213CS646
# 11 2009-05-02 2009-05-14      199         384       18938  200905023CS847
# 12 2009-05-16 2009-05-27      306         384       19067  200905163CS746
#
#     Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0           348.58           758.0           6             0.0       4548.0
# 9           348.58           758.0           6             0.0       4548.0
# 10          348.58           758.0           6             0.0       4548.0
# 11          348.58           758.0           6             0.0       4548.0
# 12          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
df.groupby("Produto")["TempoEnvio"].mean()
# Out:
# Produto
# Adventure Works Laptop15.4W M1548 Black            8.300813
# Adventure Works Laptop15.4W M1548 Red              9.052174
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black        8.674157
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey         8.255319
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White        8.688889
# Fabrikam Trendsetter 2/3'' 17mm X100 Black         8.165049
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey          8.754237
# Headphone Adapter for Contoso Phone E130 Silver    8.298851
# Headphone Adapter for Contoso Phone E130 White     8.647059
# Name: TempoEnvio, dtype: float64

# %%
df.groupby("Produto")["TempoEnvio"].mean().plot.bar(title="")

# %%
df.groupby([df["Data Venda"].dt.year,"Marca"])["lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works     42170.26
#             Contoso               392.00
#             Fabrikam           189418.41
# 2009        Adventure Works     55271.70
#             Contoso               450.80
#             Fabrikam           137648.55
# Name: lucro, dtype: float64
